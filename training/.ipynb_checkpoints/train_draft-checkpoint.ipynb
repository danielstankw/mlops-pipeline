# %%
import os 
import pandas as pd
import numpy as np
import optuna
import xgboost as xgb
import mlflow
from mlflow.tracking import MlflowClient
from mlflow.entities import ViewType
import requests
import zipfile

from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score, recall_score, roc_auc_score, precision_score, average_precision_score

from datetime import datetime
# Out:
# /home/daniel/anaconda3/envs/myenv/lib/python3.9/site-packages/pydantic/_internal/_fields.py:127: UserWarning: Field "model_server_url" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# /home/daniel/anaconda3/envs/myenv/lib/python3.9/site-packages/pydantic/_internal/_config.py:269: UserWarning: Valid config keys have changed in V2:
# * 'schema_extra' has been renamed to 'json_schema_extra'
#   warnings.warn(message, UserWarning)

# %%
DATA_LINK = "https://raw.githubusercontent.com/danielstankw/data-mlops/5d593d3e7ea9c19bb154a3eb5a8527ce88543a97/archive.zip"
USE_MLFLOW = False

# %%
MLFLOW_TRACKING_URI = "http://127.0.0.1:5000"
client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)

# %%
def download_data(url: str) -> pd.DataFrame:
    """
    Download data from a given URL, unzip it to data_dir folder, and return the data as a DataFrame.
    
    Parameters:
    - url (str): The URL of the data to be downloaded.
    
    Returns:
    - pd.DataFrame: The downloaded data as a DataFrame.
    """

    data_dir = 'data'
    
    # Create 'data' directory if it doesn't exist
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)

    # Download the file
    zip_path = os.path.join(data_dir, 'archive.zip')
    response = requests.get(url)
    with open(zip_path, 'wb') as file:
        file.write(response.content)

    # Unzip the file into the 'data' directory
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(data_dir)

    # Remove the residual archive.zip file
    os.remove(zip_path)

    # Fetch the name of the .csv files
    csv_files = [file for file in os.listdir(data_dir) if file.endswith('.csv')]
    if not csv_files:
        raise ValueError("No CSV files found in the downloaded data.")
    
    # Read the first CSV file into a DataFrame
    df = pd.read_csv(os.path.join(data_dir, csv_files[0]))

    return df

def preprocess_data(df: pd.DataFrame) -> (pd.DataFrame, pd.Series):
    """
    Preprocess the given data by handling duplicates, and separating the target column.
    
    Parameters:
    - df (pd.DataFrame): The input data to be preprocessed.
    
    Returns:
    - pd.DataFrame: The preprocessed data.
    - pd.Series: The target column values.
    """
    
    # Handling duplicates
    df = df.drop_duplicates()

    # Drop rows where gender is 'Other'
    df = df[df['gender'] != 'Other']

    # Recategorize the 'smoking_history' column
    def recategorize_smoking_status(smoking_status: str) -> str:
        """Recategorize smoking status based on given conditions."""
        mapping = {
            'never': 'non_smoker',
            'No Info': 'no_info',
            'current': 'current',
            'ever': 'past_smoker',
            'former': 'past_smoker',
            'not current': 'past_smoker'
        }
        return mapping.get(smoking_status, smoking_status)

    df['smoking_history'] = df['smoking_history'].apply(recategorize_smoking_status)

    # Separate the target column
    target = 'diabetes'
    y = df[target].copy()
    df.drop(target, axis=1, inplace=True)

    return df, y

def split_data(df: pd.DataFrame, y: pd.Series, verbose: bool = False) -> tuple:
    """
    Split the data into training, validation, and test sets.
    
    Parameters:
    - df (pd.DataFrame): The input data.
    - y (pd.Series): The target values.
    - verbose (bool): If True, print the percentage of diabetic values in each set.
    
    Returns:
    - tuple: Training, validation, and test sets for both data and target values.
    """
    
    df_train, df_temp, y_train, y_temp = train_test_split(
        df, y, test_size=0.2, random_state=42, stratify=y
    )
    
    df_val, df_test, y_val, y_test = train_test_split(
        df_temp, y_temp, test_size=0.5, random_state=42, stratify=y_temp
    )

    if verbose:
        print(f'[%] of diabetic values in the train set: {np.round(y_train.sum() / len(y_train) * 100, 2)}')
        print(f'[%] of diabetic values in the validation set: {np.round(y_val.sum() / len(y_val) * 100, 2)}')
        print(f'[%] of diabetic values in the test set: {np.round(y_test.sum() / len(y_test) * 100, 2)}')

    return df_train, df_val, df_test, y_train, y_val, y_test

def calculate_metrics(y_true: pd.Series, y_pred: pd.Series) -> tuple:
    """
    Calculate various metrics to evaluate the performance of a classification model.
    
    Parameters:
    - y_true (pd.Series): The true target values.
    - y_pred (pd.Series): The predicted target values.
    
    Returns:
    - tuple: AUC, F1 score, precision, recall, average precision, and accuracy.
    """
    
    auc = roc_auc_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    avg_precision = average_precision_score(y_true, y_pred)
    accuracy = accuracy_score(y_true, y_pred)

    return auc, f1, precision, recall, avg_precision, accuracy


def optimize_params(train, y_train, dvalid, y_val, n_trials=3):
    """
    Optimize hyperparameters for an XGBoost classifier using Optuna.
    
    Parameters:
    - X_train, y_train: Training data and labels.
    - X_val, y_val: Validation data and labels.
    - n_trials (int): Number of trials for hyperparameter optimization.
    
    Returns:
    - optuna.study.Study: Study object with optimization results.
    """

    # dtrain = xgb.DMatrix(X_train, label=y_train)
    # dvalid = xgb.DMatrix(X_val, label=y_val)
    
    def objective(trial):
        """
        Objective function for Optuna optimization.
        
        Parameters:
        - trial: Optuna trial object.
        
        Returns:
        - float: F1 score for the given hyperparameters.
        """

        with mlflow.start_run():
            mlflow.set_tag("model", "xgboost")

            constant_params = {
                "objective": "binary:logistic",
                "eval_metric" : "logloss"}
            
            hyper_params = {
                "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
                "max_depth": trial.suggest_int("max_depth", 1, 10),
                "subsample": trial.suggest_float("subsample", 0.05, 1.0),
                "colsample_bytree": trial.suggest_float("colsample_bytree", 0.05, 1.0),
                "min_child_weight": trial.suggest_int("min_child_weight", 1, 20)
            }

            combined_params = {**constant_params, **hyper_params}

            mlflow.log_params(combined_params)

            classifier = xgb.train(
                combined_params,
                dtrain,
                evals=[(dvalid, "validation")],
                verbose_eval=1,
                early_stopping_rounds=10,
                num_boost_round=1000
            )
            
            # output are the probabilities, we need to convert to the binary classes
            y_pred_proba = classifier.predict(dvalid)
            y_pred = (y_pred_proba > 0.5).astype(int)
            
            f1_metric = f1_score(y_true=y_val, y_pred=y_pred) 

            mlflow.log_metric('f1', f1_metric)
            
        return f1_metric
    
    # To execute the optimization, we create a study object and pass 
    # the objective function to the optimize method.
    study = optuna.create_study(direction='maximize')
    study.optimize(objective, n_trials=n_trials)

    return study




def train_optimized_model(study, dtrain, y_train, dvalid, y_val):
    """
    Train an XGBoost classifier using the best parameters from a given study.
    
    Parameters:
    - study: Optuna study object with optimization results.
    - train_data, val_data: Training and validation data.
    - y_train, y_val: Training and validation labels.
    """
    
    # dtrain = xgb.DMatrix(X_train, label=y_train)
    # dvalid = xgb.DMatrix(X_val, label=y_val)
    
    with mlflow.start_run():
        
        constant_params = {
            "objective": "binary:logistic"}

        # Combine constant and hyperopt parameters
        combined_params = {**study.best_params, **constant_params}
        mlflow.log_params(combined_params)

        classifier = xgb.train(
            combined_params,
            dtrain,
            evals=[(dvalid, "validation")],
            verbose_eval=1,
            early_stopping_rounds=10,
            num_boost_round=1000
        )
        
        y_pred_proba = classifier.predict(dvalid)
        y_pred = (y_pred_proba > 0.5).astype(int)
        
        f1_metric = f1_score(y_val, y_pred)
        print(f'F1 Score: {f1_metric}')

        mlflow.log_metric("f1", f1_metric)
        mlflow.sklearn.log_model(classifier, artifact_path="models_mlflow")

        print(f"Default artifacts URI: '{mlflow.get_artifact_uri()}'")

# %%
df_original = download_data(url=DATA_LINK)
df = df_original.copy()

# preprocess data
df, y = preprocess_data(df)

# data split
df_train, df_val, df_test, y_train, y_val, y_test = split_data(df, y)

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (76902, 9613, 9613)

# %%
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
print(mlflow.get_tracking_uri())
# set an experiment, if it doesnt exist create one
mlflow.set_experiment(experiment_name='final-experiment')
# Out:
# 2023/09/19 13:53:48 INFO mlflow.tracking.fluent: Experiment with name 'final-experiment' does not exist. Creating a new experiment.
# http://127.0.0.1:5000
# <Experiment: artifact_location='mlflow-artifacts:/1', creation_time=1695131628721, experiment_id='1', last_update_time=1695131628721, lifecycle_stage='active', name='final-experiment', tags={}>

# %%
import pickle

# %%
# features
categorical_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()
numerical_cols = df.select_dtypes(exclude=['object', 'category']).columns.tolist()
all_features = categorical_cols + numerical_cols

# one-hot encoding categorical features
dv = DictVectorizer()
train_dicts = df_train[all_features].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[all_features].to_dict(orient='records')
X_val = dv.transform(val_dicts)

os.makedirs("model", exist_ok=True)
with open("model/preprocessor.b", "wb") as f:
    pickle.dump(dv, f)

dtrain = xgb.DMatrix(X_train, label=y_train)
dvalid = xgb.DMatrix(X_val, label=y_val)
# Out:
# /home/daniel/anaconda3/envs/myenv/lib/python3.9/site-packages/xgboost/data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):

# %%
study = optimize_params(dtrain, y_train, dvalid, y_val, n_trials=2)
# Out:
# [I 2023-09-19 13:53:52,291] A new study created in memory with name: no-name-6231814d-1721-400b-bb0c-99ce62971be6
# [0]	validation-logloss:0.32097
# [1]	validation-logloss:0.32050
# [2]	validation-logloss:0.32003
# [3]	validation-logloss:0.31956
# [4]	validation-logloss:0.31945
# [5]	validation-logloss:0.31899
# [6]	validation-logloss:0.31869
# [7]	validation-logloss:0.31823
# [8]	validation-logloss:0.31777
# [9]	validation-logloss:0.31743
# [10]	validation-logloss:0.31713
# [11]	validation-logloss:0.31680
# [12]	validation-logloss:0.31651
# [13]	validation-logloss:0.31622
# [14]	validation-logloss:0.31593
# [15]	validation-logloss:0.31583
# [16]	validation-logloss:0.31549
# [17]	validation-logloss:0.31504
# [18]	validation-logloss:0.31460
# [19]	validation-logloss:0.31416
# [20]	validation-logloss:0.31388
# [21]	validation-logloss:0.31359
# [22]	validation-logloss:0.31316
# [23]	validation-logloss:0.31272
# [24]	validation-logloss:0.31262
# [25]	validation-logloss:0.31218
# [26]	validation-logloss:0.31186
# [27]	validation-logloss:0.31143
# [28]	validation-logloss:0.31133
# [29]	validation-logloss:0.31090
# [30]	validation-logloss:0.31063
# [31]	validation-logloss:0.31020
# [32]	validation-logloss:0.30994
# [33]	validation-logloss:0.30951
# [34]	validation-logloss:0.30909
# [35]	validation-logloss:0.30867
# [36]	validation-logloss:0.30826
# [37]	validation-logloss:0.30784
# [38]	validation-logloss:0.30774
# [39]	validation-logloss:0.30733
# [40]	validation-logloss:0.30692
# [41]	validation-logloss:0.30651
# [42]	validation-logloss:0.30610
# [43]	validation-logloss:0.30570
# [44]	validation-logloss:0.30529
# [45]	validation-logloss:0.30519
# [46]	validation-logloss:0.30479
# [47]	validation-logloss:0.30454
# [48]	validation-logloss:0.30424
# [49]	validation-logloss:0.30399
# [50]	validation-logloss:0.30359
# [51]	validation-logloss:0.30330
# [52]	validation-logloss:0.30290
# [53]	validation-logloss:0.30265
# [54]	validation-logloss:0.30226
# [55]	validation-logloss:0.30187
# [56]	validation-logloss:0.30158
# [57]	validation-logloss:0.30133
# [58]	validation-logloss:0.30095
# [59]	validation-logloss:0.30070
# [60]	validation-logloss:0.30032
# [61]	validation-logloss:0.29993
# [62]	validation-logloss:0.29984
# [63]	validation-logloss:0.29945
# [64]	validation-logloss:0.29907
# [65]	validation-logloss:0.29870
# [66]	validation-logloss:0.29842
# [67]	validation-logloss:0.29804
# [68]	validation-logloss:0.29780
# [69]	validation-logloss:0.29743
# [70]	validation-logloss:0.29715
# [71]	validation-logloss:0.29678
# [72]	validation-logloss:0.29641
# [73]	validation-logloss:0.29618
# [74]	validation-logloss:0.29590
# [75]	validation-logloss:0.29554
# [76]	validation-logloss:0.29530
# [77]	validation-logloss:0.29494
# [78]	validation-logloss:0.29458
# [79]	validation-logloss:0.29431
# [80]	validation-logloss:0.29395
# [81]	validation-logloss:0.29360
# [82]	validation-logloss:0.29324
# [83]	validation-logloss:0.29289
# [84]	validation-logloss:0.29266
# [85]	validation-logloss:0.29244
# [536]	validation-logloss:0.20873
# [537]	validation-logloss:0.20862
# [538]	validation-logloss:0.20848
# [539]	validation-logloss:0.20834
# [540]	validation-logloss:0.20824
# [541]	validation-logloss:0.20813
# [542]	validation-logloss:0.20802
# [543]	validation-logloss:0.20793
# [544]	validation-logloss:0.20782
# [545]	validation-logloss:0.20777
# [546]	validation-logloss:0.20764
# [547]	validation-logloss:0.20750
# [548]	validation-logloss:0.20737
# [549]	validation-logloss:0.20726
# [550]	validation-logloss:0.20713
# [551]	validation-logloss:0.20699
# [552]	validation-logloss:0.20693
# [553]	validation-logloss:0.20680
# [554]	validation-logloss:0.20666
# [555]	validation-logloss:0.20657
# [556]	validation-logloss:0.20648
# [557]	validation-logloss:0.20634
# [558]	validation-logloss:0.20624
# [559]	validation-logloss:0.20613
# [560]	validation-logloss:0.20604
# [561]	validation-logloss:0.20598
# [562]	validation-logloss:0.20588
# [563]	validation-logloss:0.20574
# [564]	validation-logloss:0.20566
# [565]	validation-logloss:0.20556
# [566]	validation-logloss:0.20545
# [567]	validation-logloss:0.20537
# [568]	validation-logloss:0.20526
# [569]	validation-logloss:0.20513
# [570]	validation-logloss:0.20500
# [571]	validation-logloss:0.20486
# [572]	validation-logloss:0.20478
# [573]	validation-logloss:0.20464
# [574]	validation-logloss:0.20455
# [575]	validation-logloss:0.20442
# [576]	validation-logloss:0.20432
# [577]	validation-logloss:0.20419
# [578]	validation-logloss:0.20409
# [579]	validation-logloss:0.20395
# [580]	validation-logloss:0.20387
# [581]	validation-logloss:0.20374
# [582]	validation-logloss:0.20361
# [583]	validation-logloss:0.20352
# [584]	validation-logloss:0.20339
# [585]	validation-logloss:0.20329
# [586]	validation-logloss:0.20316
# [587]	validation-logloss:0.20303
# [588]	validation-logloss:0.20290
# [589]	validation-logloss:0.20277
# [590]	validation-logloss:0.20269
# [591]	validation-logloss:0.20256
# [592]	validation-logloss:0.20247
# [593]	validation-logloss:0.20237
# [594]	validation-logloss:0.20229
# [595]	validation-logloss:0.20216
# [596]	validation-logloss:0.20208
# [597]	validation-logloss:0.20195
# [598]	validation-logloss:0.20182
# [599]	validation-logloss:0.20170
# [600]	validation-logloss:0.20160
# [601]	validation-logloss:0.20150
# [602]	validation-logloss:0.20137
# [603]	validation-logloss:0.20125
# [604]	validation-logloss:0.20112
# [605]	validation-logloss:0.20104
# [606]	validation-logloss:0.20098
# [607]	validation-logloss:0.20088
# [608]	validation-logloss:0.20079
# [609]	validation-logloss:0.20066
# [610]	validation-logloss:0.20054
# [611]	validation-logloss:0.20046
# [612]	validation-logloss:0.20033
# [613]	validation-logloss:0.20021
# [614]	validation-logloss:0.20009
# [615]	validation-logloss:0.19996
# [616]	validation-logloss:0.19991
# [617]	validation-logloss:0.19983
# [618]	validation-logloss:0.19973
# [619]	validation-logloss:0.19961
# [620]	validation-logloss:0.19949
# [621]	validation-logloss:0.19939
# [622]	validation-logloss:0.19929
# [623]	validation-logloss:0.19922
# [624]	validation-logloss:0.19909
# [985]	validation-logloss:0.16923
# [986]	validation-logloss:0.16915
# [987]	validation-logloss:0.16909
# [988]	validation-logloss:0.16902
# [989]	validation-logloss:0.16895
# [990]	validation-logloss:0.16888
# [991]	validation-logloss:0.16881
# [992]	validation-logloss:0.16874
# [993]	validation-logloss:0.16867
# [994]	validation-logloss:0.16861
# [995]	validation-logloss:0.16856
# [996]	validation-logloss:0.16851
# [997]	validation-logloss:0.16844
# [998]	validation-logloss:0.16837
# [999]	validation-logloss:0.16830
# [I 2023-09-19 13:53:57,211] Trial 0 finished with value: 0.8106591865357644 and parameters: {'learning_rate': 0.0011215073243063425, 'max_depth': 2, 'subsample': 0.1418528255481938, 'colsample_bytree': 0.7738921113929147, 'min_child_weight': 18}. Best is trial 0 with value: 0.8106591865357644.
# [0]	validation-logloss:0.32131
# [1]	validation-logloss:0.32125
# [2]	validation-logloss:0.32080
# [3]	validation-logloss:0.32069
# [4]	validation-logloss:0.32060
# [5]	validation-logloss:0.32017
# [6]	validation-logloss:0.32006
# [7]	validation-logloss:0.31965
# [8]	validation-logloss:0.31922
# [9]	validation-logloss:0.31909
# [10]	validation-logloss:0.31871
# [11]	validation-logloss:0.31856
# [12]	validation-logloss:0.31820
# [13]	validation-logloss:0.31811
# [14]	validation-logloss:0.31773
# [15]	validation-logloss:0.31763
# [16]	validation-logloss:0.31722
# [17]	validation-logloss:0.31667
# [18]	validation-logloss:0.31630
# [19]	validation-logloss:0.31618
# [20]	validation-logloss:0.31607
# [21]	validation-logloss:0.31598
# [22]	validation-logloss:0.31556
# [23]	validation-logloss:0.31520
# [24]	validation-logloss:0.31506
# [25]	validation-logloss:0.31500
# [26]	validation-logloss:0.31488
# [27]	validation-logloss:0.31446
# [28]	validation-logloss:0.31433
# [29]	validation-logloss:0.31421
# [30]	validation-logloss:0.31411
# [31]	validation-logloss:0.31401
# [32]	validation-logloss:0.31365
# [33]	validation-logloss:0.31325
# [34]	validation-logloss:0.31316
# [35]	validation-logloss:0.31281
# [36]	validation-logloss:0.31272
# [37]	validation-logloss:0.31266
# [38]	validation-logloss:0.31258
# [39]	validation-logloss:0.31217
# [40]	validation-logloss:0.31163
# [41]	validation-logloss:0.31123
# [42]	validation-logloss:0.31109
# [43]	validation-logloss:0.31099
# [44]	validation-logloss:0.31085
# [45]	validation-logloss:0.31075
# [46]	validation-logloss:0.31035
# [47]	validation-logloss:0.31025
# [48]	validation-logloss:0.30987
# [49]	validation-logloss:0.30953
# [50]	validation-logloss:0.30942
# [51]	validation-logloss:0.30936
# [52]	validation-logloss:0.30901
# [53]	validation-logloss:0.30867
# [54]	validation-logloss:0.30856
# [55]	validation-logloss:0.30818
# [56]	validation-logloss:0.30811
# [57]	validation-logloss:0.30800
# [58]	validation-logloss:0.30764
# [59]	validation-logloss:0.30755
# [60]	validation-logloss:0.30703
# [61]	validation-logloss:0.30671
# [62]	validation-logloss:0.30663
# [63]	validation-logloss:0.30612
# [64]	validation-logloss:0.30605
# [65]	validation-logloss:0.30573
# [682]	validation-logloss:0.20843
# [683]	validation-logloss:0.20837
# [684]	validation-logloss:0.20815
# [685]	validation-logloss:0.20810
# [686]	validation-logloss:0.20798
# [687]	validation-logloss:0.20776
# [688]	validation-logloss:0.20755
# [689]	validation-logloss:0.20750
# [690]	validation-logloss:0.20729
# [691]	validation-logloss:0.20713
# [692]	validation-logloss:0.20699
# [693]	validation-logloss:0.20687
# [694]	validation-logloss:0.20666
# [695]	validation-logloss:0.20644
# [696]	validation-logloss:0.20630
# [697]	validation-logloss:0.20618
# [698]	validation-logloss:0.20603
# [699]	validation-logloss:0.20589
# [700]	validation-logloss:0.20575
# [701]	validation-logloss:0.20571
# [702]	validation-logloss:0.20557
# [703]	validation-logloss:0.20545
# [704]	validation-logloss:0.20540
# [705]	validation-logloss:0.20528
# [706]	validation-logloss:0.20515
# [707]	validation-logloss:0.20500
# [708]	validation-logloss:0.20488
# [709]	validation-logloss:0.20476
# [710]	validation-logloss:0.20463
# [711]	validation-logloss:0.20458
# [712]	validation-logloss:0.20455
# [713]	validation-logloss:0.20444
# [714]	validation-logloss:0.20438
# [715]	validation-logloss:0.20434
# [716]	validation-logloss:0.20422
# [717]	validation-logloss:0.20420
# [718]	validation-logloss:0.20407
# [719]	validation-logloss:0.20403
# [720]	validation-logloss:0.20392
# [721]	validation-logloss:0.20380
# [722]	validation-logloss:0.20375
# [723]	validation-logloss:0.20369
# [724]	validation-logloss:0.20355
# [725]	validation-logloss:0.20352
# [726]	validation-logloss:0.20348
# [727]	validation-logloss:0.20336
# [728]	validation-logloss:0.20322
# [729]	validation-logloss:0.20302
# [730]	validation-logloss:0.20296
# [731]	validation-logloss:0.20290
# [732]	validation-logloss:0.20274
# [733]	validation-logloss:0.20269
# [734]	validation-logloss:0.20256
# [735]	validation-logloss:0.20242
# [736]	validation-logloss:0.20237
# [737]	validation-logloss:0.20223
# [738]	validation-logloss:0.20219
# [739]	validation-logloss:0.20213
# [740]	validation-logloss:0.20208
# [741]	validation-logloss:0.20194
# [742]	validation-logloss:0.20174
# [743]	validation-logloss:0.20162
# [744]	validation-logloss:0.20151
# [745]	validation-logloss:0.20140
# [746]	validation-logloss:0.20126
# [747]	validation-logloss:0.20125
# [748]	validation-logloss:0.20120
# [749]	validation-logloss:0.20108
# [750]	validation-logloss:0.20095
# [751]	validation-logloss:0.20075
# [752]	validation-logloss:0.20070
# [753]	validation-logloss:0.20065
# [754]	validation-logloss:0.20061
# [755]	validation-logloss:0.20048
# [756]	validation-logloss:0.20045
# [757]	validation-logloss:0.20044
# [758]	validation-logloss:0.20038
# [759]	validation-logloss:0.20023
# [760]	validation-logloss:0.20020
# [761]	validation-logloss:0.20009
# [762]	validation-logloss:0.19995
# [763]	validation-logloss:0.19989
# [764]	validation-logloss:0.19986
# [765]	validation-logloss:0.19967
# [766]	validation-logloss:0.19955
# [767]	validation-logloss:0.19941
# [768]	validation-logloss:0.19937
# [769]	validation-logloss:0.19925
# [770]	validation-logloss:0.19923
# [951]	validation-logloss:0.18384
# [952]	validation-logloss:0.18382
# [953]	validation-logloss:0.18371
# [954]	validation-logloss:0.18362
# [955]	validation-logloss:0.18352
# [956]	validation-logloss:0.18343
# [957]	validation-logloss:0.18331
# [958]	validation-logloss:0.18327
# [959]	validation-logloss:0.18319
# [960]	validation-logloss:0.18315
# [961]	validation-logloss:0.18313
# [962]	validation-logloss:0.18302
# [963]	validation-logloss:0.18293
# [964]	validation-logloss:0.18289
# [965]	validation-logloss:0.18279
# [966]	validation-logloss:0.18275
# [967]	validation-logloss:0.18263
# [968]	validation-logloss:0.18262
# [969]	validation-logloss:0.18252
# [970]	validation-logloss:0.18250
# [971]	validation-logloss:0.18246
# [972]	validation-logloss:0.18236
# [973]	validation-logloss:0.18232
# [974]	validation-logloss:0.18231
# [975]	validation-logloss:0.18215
# [976]	validation-logloss:0.18213
# [977]	validation-logloss:0.18210
# [978]	validation-logloss:0.18205
# [979]	validation-logloss:0.18195
# [980]	validation-logloss:0.18194
# [981]	validation-logloss:0.18185
# [982]	validation-logloss:0.18182
# [983]	validation-logloss:0.18178
# [984]	validation-logloss:0.18174
# [985]	validation-logloss:0.18170
# [986]	validation-logloss:0.18162
# [987]	validation-logloss:0.18151
# [988]	validation-logloss:0.18139
# [989]	validation-logloss:0.18137
# [990]	validation-logloss:0.18133
# [991]	validation-logloss:0.18121
# [992]	validation-logloss:0.18110
# [993]	validation-logloss:0.18106
# [994]	validation-logloss:0.18105
# [995]	validation-logloss:0.18096
# [996]	validation-logloss:0.18091
# [997]	validation-logloss:0.18075
# [998]	validation-logloss:0.18059
# [999]	validation-logloss:0.18044
# [I 2023-09-19 13:54:04,186] Trial 1 finished with value: 0.36293436293436293 and parameters: {'learning_rate': 0.0012934440819739415, 'max_depth': 6, 'subsample': 0.6560258060443955, 'colsample_bytree': 0.3961406840266234, 'min_child_weight': 5}. Best is trial 0 with value: 0.8106591865357644.

# %%
study.best_params
# Out:
# {'learning_rate': 0.0011215073243063425,
#  'max_depth': 2,
#  'subsample': 0.1418528255481938,
#  'colsample_bytree': 0.7738921113929147,
#  'min_child_weight': 18}

# %%
# train best model
train_optimized_model(study, dtrain, y_train, dvalid, y_val)
# Out:
# [0]	validation-logloss:0.32097
# [1]	validation-logloss:0.32050
# [2]	validation-logloss:0.32003
# [3]	validation-logloss:0.31956
# [4]	validation-logloss:0.31945
# [5]	validation-logloss:0.31899
# [6]	validation-logloss:0.31869
# [7]	validation-logloss:0.31823
# [8]	validation-logloss:0.31777
# [9]	validation-logloss:0.31743
# [10]	validation-logloss:0.31713
# [11]	validation-logloss:0.31680
# [12]	validation-logloss:0.31651
# [13]	validation-logloss:0.31622
# [14]	validation-logloss:0.31593
# [15]	validation-logloss:0.31583
# [16]	validation-logloss:0.31549
# [17]	validation-logloss:0.31504
# [18]	validation-logloss:0.31460
# [19]	validation-logloss:0.31416
# [20]	validation-logloss:0.31388
# [21]	validation-logloss:0.31359
# [22]	validation-logloss:0.31316
# [23]	validation-logloss:0.31272
# [563]	validation-logloss:0.20574
# [564]	validation-logloss:0.20566
# [565]	validation-logloss:0.20556
# [566]	validation-logloss:0.20545
# [567]	validation-logloss:0.20537
# [568]	validation-logloss:0.20526
# [569]	validation-logloss:0.20513
# [570]	validation-logloss:0.20500
# [571]	validation-logloss:0.20486
# [572]	validation-logloss:0.20478
# [573]	validation-logloss:0.20464
# [574]	validation-logloss:0.20455
# [575]	validation-logloss:0.20442
# [576]	validation-logloss:0.20432
# [577]	validation-logloss:0.20419
# [578]	validation-logloss:0.20409
# [579]	validation-logloss:0.20395
# [580]	validation-logloss:0.20387
# [581]	validation-logloss:0.20374
# [582]	validation-logloss:0.20361
# [583]	validation-logloss:0.20352
# [584]	validation-logloss:0.20339
# [585]	validation-logloss:0.20329
# [586]	validation-logloss:0.20316
# [587]	validation-logloss:0.20303
# [588]	validation-logloss:0.20290
# [589]	validation-logloss:0.20277
# [590]	validation-logloss:0.20269
# [591]	validation-logloss:0.20256
# [592]	validation-logloss:0.20247
# [593]	validation-logloss:0.20237
# [594]	validation-logloss:0.20229
# [595]	validation-logloss:0.20216
# [596]	validation-logloss:0.20208
# [597]	validation-logloss:0.20195
# [598]	validation-logloss:0.20182
# [599]	validation-logloss:0.20170
# [600]	validation-logloss:0.20160
# [601]	validation-logloss:0.20150
# [602]	validation-logloss:0.20137
# [603]	validation-logloss:0.20125
# [604]	validation-logloss:0.20112
# [605]	validation-logloss:0.20104
# [606]	validation-logloss:0.20098
# [607]	validation-logloss:0.20088
# [608]	validation-logloss:0.20079
# [609]	validation-logloss:0.20066
# [610]	validation-logloss:0.20054
# [611]	validation-logloss:0.20046
# [612]	validation-logloss:0.20033
# [613]	validation-logloss:0.20021
# [614]	validation-logloss:0.20009
# [615]	validation-logloss:0.19996
# [616]	validation-logloss:0.19991
# [617]	validation-logloss:0.19983
# [618]	validation-logloss:0.19973
# [619]	validation-logloss:0.19961
# [620]	validation-logloss:0.19949
# [621]	validation-logloss:0.19939
# [622]	validation-logloss:0.19929
# [623]	validation-logloss:0.19922
# [624]	validation-logloss:0.19909
# [625]	validation-logloss:0.19897
# [626]	validation-logloss:0.19885
# [627]	validation-logloss:0.19873
# [628]	validation-logloss:0.19861
# [629]	validation-logloss:0.19852
# [630]	validation-logloss:0.19840
# [631]	validation-logloss:0.19828
# [632]	validation-logloss:0.19819
# [633]	validation-logloss:0.19807
# [634]	validation-logloss:0.19795
# [635]	validation-logloss:0.19784
# [636]	validation-logloss:0.19774
# [637]	validation-logloss:0.19762
# [638]	validation-logloss:0.19754
# [639]	validation-logloss:0.19742
# [640]	validation-logloss:0.19730
# [641]	validation-logloss:0.19726
# [642]	validation-logloss:0.19716
# [643]	validation-logloss:0.19709
# [644]	validation-logloss:0.19697
# [645]	validation-logloss:0.19685
# [646]	validation-logloss:0.19673
# [647]	validation-logloss:0.19662
# [648]	validation-logloss:0.19650
# [649]	validation-logloss:0.19638
# [650]	validation-logloss:0.19627
# [651]	validation-logloss:0.19615
# [652]	validation-logloss:0.19607
# [922]	validation-logloss:0.17334
# [923]	validation-logloss:0.17326
# [924]	validation-logloss:0.17322
# [925]	validation-logloss:0.17314
# [926]	validation-logloss:0.17306
# [927]	validation-logloss:0.17298
# [928]	validation-logloss:0.17290
# [929]	validation-logloss:0.17285
# [930]	validation-logloss:0.17279
# [931]	validation-logloss:0.17272
# [932]	validation-logloss:0.17264
# [933]	validation-logloss:0.17256
# [934]	validation-logloss:0.17252
# [935]	validation-logloss:0.17245
# [936]	validation-logloss:0.17237
# [937]	validation-logloss:0.17229
# [938]	validation-logloss:0.17225
# [939]	validation-logloss:0.17218
# [940]	validation-logloss:0.17212
# [941]	validation-logloss:0.17206
# [942]	validation-logloss:0.17198
# [943]	validation-logloss:0.17191
# [944]	validation-logloss:0.17183
# [945]	validation-logloss:0.17179
# [946]	validation-logloss:0.17174
# [947]	validation-logloss:0.17166
# [948]	validation-logloss:0.17159
# [949]	validation-logloss:0.17151
# [950]	validation-logloss:0.17144
# [951]	validation-logloss:0.17136
# [952]	validation-logloss:0.17129
# [953]	validation-logloss:0.17122
# [954]	validation-logloss:0.17117
# [955]	validation-logloss:0.17112
# [956]	validation-logloss:0.17106
# [957]	validation-logloss:0.17098
# [958]	validation-logloss:0.17092
# [959]	validation-logloss:0.17084
# [960]	validation-logloss:0.17079
# [961]	validation-logloss:0.17075
# [962]	validation-logloss:0.17068
# [963]	validation-logloss:0.17060
# [964]	validation-logloss:0.17055
# [965]	validation-logloss:0.17048
# [966]	validation-logloss:0.17040
# [967]	validation-logloss:0.17033
# [968]	validation-logloss:0.17029
# [969]	validation-logloss:0.17022
# [970]	validation-logloss:0.17015
# [971]	validation-logloss:0.17010
# [972]	validation-logloss:0.17004
# [973]	validation-logloss:0.16997
# [974]	validation-logloss:0.16990
# [975]	validation-logloss:0.16982
# [976]	validation-logloss:0.16977
# [977]	validation-logloss:0.16969
# [978]	validation-logloss:0.16962
# [979]	validation-logloss:0.16955
# [980]	validation-logloss:0.16950
# [981]	validation-logloss:0.16945
# [982]	validation-logloss:0.16939
# [983]	validation-logloss:0.16935
# [984]	validation-logloss:0.16928
# [985]	validation-logloss:0.16923
# [986]	validation-logloss:0.16915
# [987]	validation-logloss:0.16909
# [988]	validation-logloss:0.16902
# [989]	validation-logloss:0.16895
# [990]	validation-logloss:0.16888
# [991]	validation-logloss:0.16881
# [992]	validation-logloss:0.16874
# [993]	validation-logloss:0.16867
# [994]	validation-logloss:0.16861
# [995]	validation-logloss:0.16856
# [996]	validation-logloss:0.16851
# [997]	validation-logloss:0.16844
# [998]	validation-logloss:0.16837
# [999]	validation-logloss:0.16830
# F1 Score: 0.8106591865357644
# Default artifacts URI: 'mlflow-artifacts:/1/3a0c5346faef4766b6db6ca9f3c4782d/artifacts'

# %%
logged_model = 'runs:/fc485e48d0934b68a8a6aa6703b8b2fa/models_mlflow'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)
# Out:
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]
